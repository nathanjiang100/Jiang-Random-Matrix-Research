# %%
#noiseless
    #recover rank n subspace
    #guess n
#sparcity
    #recover rank 1
    #guess n
    #error corrections
#matrix is too big
    #linear sketching
    #random projection
    #averaging
#start drafting

import numpy as np
import scipy as sp
from scipy import linalg
from matplotlib import pyplot as plt 

r = 1
n = 10000
a = 100
rank = 1
N = rank
mu, sigma = 0, 1
lmax = (1 + np.sqrt(r)) ** 2
lmin = (1 - np.sqrt(r)) ** 2
signal = np.random.randint(-10,10,(int(n * r),rank))
Q = signal @ signal.T
origin = np.array([[0, 0],[0, 0]]) # origin point
proj = np.random.choice(2, (int(n * r/a),int(n*r)),p=[0.95,0.05])
prog = proj

def denoise(matrix):
    nrows = matrix.shape[0]
    ncols = matrix.shape[1]
    matrix = matrix / (nrows*ncols)
    matrix = matrix * 1e6
    matrix[:,:] = np.log2(np.abs(matrix[:,:]+1))
    for i in range(0, matrix.shape[1]-1):
        matrix[:,i] = (matrix[:,i] - np.mean(matrix[:,i].all()))*sigma/np.std(matrix[:,i])

def genmatrix():
    X = np.random.randn(int(n * r), n)
    D = np.diag(np.diag(proj))
    P = Q + X
    A = proj @ P
    denoise(A)
    matrix = A @ A.T / n
    return matrix
    del matrix, X, B, A

def eigen(matrix):
    eigs, eivecs = np.linalg.eigh(matrix)
    count = 0
    for j in range(0,matrix.shape[0]-1):
        if eigs[j] == 0:
            count = count + 1
    x = eigs[np.abs(eigs) > 50*n*lmax/rank]
    vecs = eivecs[:, np.arange(int(n*r/a) - x.shape[0],int(n*r/a),1)]
    print('signal:')
    print(signal)
    print('Sparce matrix')
    print('zero eigenvalues = %0.1f' % count)
    print('corresponding eigenvectors:')
    print(eivecs[:,np.arange(0,count-1,1)])
    print('signal eigenvalues:')
    print(x)
    print('corresponding eigenvectors:')
    print(vecs)
    guess = x.shape[0]
    print ('guess rank = %0.1f' % guess)
    if guess == rank:
        print('True')
    else:
        print('False')


    if rank == 1:
        sigproj = proj @ signal
        theta = np.arccos((np.dot(sigproj.T,vecs[:,x.shape[0]-1])/np.sqrt(np.dot(sigproj.T,sigproj)*np.dot(vecs[:,x.shape[0]-1].T,vecs[:,x.shape[0]-1]))))*(180/np.pi)
        print('theta (degrees) =')
        print(theta)
        plt.quiver(*origin, sigproj[:,rank-1][0], sigproj[:,rank-1][1], lw =0.5, alpha=0.1, color="red", scale=0.5)
        plt.quiver(*origin, -sigproj[:,rank-1][0], -sigproj[:,rank-1][1], lw =0.5, alpha=0.1, color="red", scale=0.5)
        plt.quiver(*origin, 500*vecs[:,x.shape[0]-1][0], 500*vecs[:,x.shape[0]-1][1], lw =0.5, alpha=0.1, color="orange", scale=0.5)
        plt.ylim(-1,1)
        plt.show()
    sigguess = prog.T @ np.linalg.inv(proj @ prog.T) @ vecs
    sigguess[:,:] = np.abs(np.rint(sigguess[:,:]))
    if sigguess.all() == signal.all():
        print('signal retrieved')
    else:
        print('signal unretrieved')
    
    plt.title("eigenvalues")
    plt.hist(eigs, density=True, histtype='stepfilled', alpha=0.5, bins=100, ec="k")
    plt.xlabel("eigenvalues")
    plt.ylabel("density")
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    plt.xlim(0,5)
    plt.ylim(0,6)
    
    xx = np.linspace(lmin, lmax, 1000)
    if r <= 1:  
        yy = np.sqrt((lmax - xx) * (xx - lmin)) / (2 * np.pi * r * xx)
        plt.plot(xx, yy, lw=4, alpha=0.7, color="orange")
        plt.text(0.95 * lmin, -0.1 * lmax, r"$\lambda^-$", color="teal")
        plt.text(0.95 * lmax, -0.1 * lmax, r"$\lambda^+$", color="#E78AC3")

    else: 
        yy = (1-1/r) + np.sqrt((lmax - xx) * (xx - lmin)) / (2 * np.pi * r * xx) #not able to input dirac-delta and obtain convergence

    plt.show()


    eivects = np.reshape(vecs,(vecs.shape[0]*vecs.shape[1],1),order='C')
    eivects = eivects[np.abs(eivects) > 1e-5]
    plt.title("eigenvector components")
    plt.hist(eivects, density=True, histtype='stepfilled', alpha=0.5, bins=int(n/10), ec="k")
    plt.xlabel("eigenvectors")
    plt.ylabel("density")
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    xx = np.linspace(-1, 1, 1000)
    plt.show()

    plt.title("Signal Eigenvector direction")
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    plt.ylim(0,1)
    for i in range(1, vecs.shape[1]):
        V = vecs[:,i]
        V1 = np.array([V[np.random.randint(1, matrix.shape[0] - 1, 1)], V[np.random.randint(1, matrix.shape[0] - 1, 1)]])
        Vn = V1 / (2*np.sqrt(V1.T @ V1))
        if Vn[1] >= 0:    
            plt.quiver(*origin, Vn[0], Vn[1], lw =0.5, alpha=0.01, color="blue", scale=1)
        else:
            plt.quiver(*origin, - Vn[0], - Vn[1], lw =0.01, alpha=0.05, color="blue", scale=1)

    plt.show()

    if N == 1:
        return theta

theta = np.zeros((1,12))
Tm = np.zeros((int(n * r/a), int(n * r/a)))
T = np.zeros((int(n * r/a),(int(n * r/a))))
def sketch():
    matrix = genmatrix()
    theta = eigen(matrix)
    print(matrix)
    return matrix, theta

T1, theta[:,0] = sketch()
T2, theta[:,1] = sketch()
T3, theta[:,2] = sketch()
T4, theta[:,3] = sketch()
T5, theta[:,4] = sketch()
T6, theta[:,5] = sketch()
T7, theta[:,6] = sketch()
T8, theta[:,7] = sketch()
T9, theta[:,8] = sketch()
T10, theta[:,9] = sketch()
for j in range(0,int(n*r/a)):
    Tm[:,j] = (T1[:,j]+T2[:,j]+T3[:,j]+T4[:,j]+T5[:,j]+T6[:,j]+T7[:,j]+T8[:,j]+T9[:,j]+T10[:,j])/10
    
theta[:,11] = eigen(Tm)

for i in range(0,12):
    if 90 <= theta[:,i] <= 180:
        theta[:,i] = 180 - theta[:,i]

theta[:,10] = np.mean(theta[:,np.arange(0,10)])
print(Tm)
xspan = np.array(['T1','T2','T3','T4','T5','T6','T7','T8','T9','T10','μ(1:10)','Tm'])
plt.title("Error Margin per Projection")
plt.scatter(xspan[np.arange(0,10)],theta[:,np.arange(0,10)])
plt.scatter(xspan[np.arange(10,12)],theta[:,np.arange(10,12)],color="Red")
plt.xlabel("Projection")
plt.ylabel("Error (degrees)")
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show
# Out:
# signal:
# [[ 3]
#  [-5]
#  [-6]
#  ...
#  [-7]
#  [-6]
#  [ 7]]
# Sparce matrix
# zero eigenvalues = 0.0
# corresponding eigenvectors:
# []
# signal eigenvalues:
# [2.05992898e+08]
# corresponding eigenvectors:
# [[ 0.0537035 ]
#  [ 0.05007865]
#  [ 0.06988736]
#  [ 0.03874259]
#  [ 0.0605907 ]
#  [ 0.07068412]
#  [ 0.02865494]
#  [ 0.08924669]
#  [ 0.05820515]
#  [ 0.10095343]
#  [-0.00285648]
#  [ 0.07994958]
#  [ 0.06218662]
#  [ 0.10014538]
#  [ 0.07430744]
#  [ 0.12358088]
#  [ 0.16236741]
#  [ 0.09248802]
#  [ 0.12639125]
#  [ 0.06298638]
#  [ 0.03475651]
#  [ 0.2100168 ]
#  [ 0.13570054]
#  [ 0.0444158 ]
#  [ 0.02017183]
#  [ 0.09811419]
#  [ 0.09086169]
#  [ 0.02542658]
#  [ 0.02424123]
#  [ 0.14782241]
#  [ 0.06542441]
#  [ 0.08278902]
#  [ 0.06300777]
#  [ 0.03556623]
#  [ 0.10945308]
#  [ 0.08321376]
#  [ 0.05048194]
#  [ 0.10945425]
#  [ 0.13729017]
#  [ 0.12316398]
#  [ 0.11752861]
#  [ 0.1441986 ]
#  [ 0.0181655 ]
#  [ 0.08480312]
#  [ 0.07955989]
#  [ 0.03592168]
#  [ 0.1227688 ]
#  [ 0.07996863]
#  [ 0.11591736]
#  [ 0.18339174]
#  [ 0.08925243]
#  [ 0.15187262]
#  [ 0.11630869]
#  [ 0.08077412]
#  [ 0.06138592]
#  [ 0.04603291]
#  [ 0.09003894]
#  [ 0.14055624]
#  [ 0.18577537]
#  [ 0.02989627]
#  [ 0.12640576]
#  [ 0.1223554 ]
#  [ 0.09653767]
#  [ 0.09768659]
#  [ 0.1902403 ]
#  [ 0.17367821]
#  [ 0.11870822]
#  [ 0.09408069]
#  [ 0.06705263]
#  [ 0.05694485]
#  [ 0.15185233]
#  [ 0.10217321]
#  [ 0.00646466]
#  [ 0.12681487]
#  [-0.0072594 ]
#  [ 0.04927262]
#  [ 0.1611272 ]
#  [ 0.11148225]
#  [ 0.05735091]
#  [ 0.14901514]
#  [ 0.12196875]
#  [ 0.11673108]
#  [ 0.13609479]
#  [-0.0048462 ]
#  [ 0.04442006]
#  [ 0.05169588]
#  [ 0.07834732]
#  [ 0.08399726]
#  [ 0.04280039]
#  [ 0.07552323]
#  [ 0.1086664 ]
#  [ 0.1457988 ]
#  [ 0.10256808]
#  [ 0.07878136]
#  [ 0.07916306]
#  [ 0.06905783]
#  [ 0.07387874]
#  [ 0.12196306]
#  [ 0.11186339]
#  [ 0.05370755]]
# guess rank = 1.0
# True
# theta (degrees) =
# [[179.99128838]]
# signal retrieved
# /var/folders/hh/nh2dbgg13m91wbj__m66m8gr0000gn/T/ipykernel_12799/539390486.py:106: RuntimeWarning: invalid value encountered in divide
#   yy = np.sqrt((lmax - xx) * (xx - lmin)) / (2 * np.pi * r * xx)
# [[ 594559.51076491  554002.46150454  773129.67671045 ... 1349216.83803052
#   1237498.52588523  594143.41805646]
#  [ 554002.46150454  517102.99843386  720949.09346025 ... 1258144.30514519
#   1153968.6226903   554044.83762953]
#  [ 773129.67671045  720949.09346025 1006576.43039478 ... 1755814.04377048
#   1610420.86159985  773192.33831165]
#  ...
#  [1349216.83803052 1258144.30514519 1755814.04377048 ... 3064612.23070356
#   2810396.93837553 1349325.96180956]
#  [1237498.52588523 1153968.6226903  1610420.86159985 ... 2810396.93837553
#   2578125.88990333 1237580.10395666]
#  [ 594143.41805646  554044.83762953  773192.33831165 ... 1349325.96180956
#   1237580.10395666  594692.83476199]]
# signal:
# [[ 3]
#  [-5]
#  [-6]
#  ...
#  [-7]
#  [-6]
#  [ 7]]
# Sparce matrix
# zero eigenvalues = 0.0
# corresponding eigenvectors:
# []
# signal eigenvalues:
# [2.06030335e+08]
# corresponding eigenvectors:
# [[ 0.05370668]
#  [ 0.0500779 ]
#  [ 0.06985632]
#  [ 0.03881105]
#  [ 0.06058878]
#  [ 0.07067469]
#  [ 0.02867781]
#  [ 0.08924468]
#  [ 0.05813583]
#  [ 0.10097042]
#  [-0.00279699]
#  [ 0.07996496]
#  [ 0.06220387]
#  [ 0.10013666]
#  [ 0.0743095 ]
#  [ 0.12359308]
#  [ 0.16234018]
#  [ 0.09248835]
#  [ 0.1263735 ]
#  [ 0.06301308]
#  [ 0.03472706]
#  [ 0.21001608]
#  [ 0.13569099]
#  [ 0.0444465 ]
#  [ 0.02016883]
#  [ 0.09811524]
#  [ 0.09085963]
#  [ 0.02544161]
#  [ 0.02421872]
#  [ 0.14783516]
#  [ 0.06541258]
#  [ 0.08278964]
#  [ 0.06299641]
#  [ 0.03556576]
#  [ 0.10944634]
#  [ 0.08319794]
#  [ 0.05049827]
#  [ 0.10944425]
#  [ 0.13730637]
#  [ 0.12318845]
#  [ 0.11749945]
#  [ 0.14418031]
#  [ 0.01820726]
#  [ 0.08482647]
#  [ 0.07955709]
#  [ 0.03595548]
#  [ 0.12278657]
#  [ 0.07998114]
#  [ 0.1159162 ]
#  [ 0.18334366]
#  [ 0.08925044]
#  [ 0.15183351]
#  [ 0.11632341]
#  [ 0.0807865 ]
#  [ 0.06138412]
#  [ 0.04605489]
#  [ 0.09004565]
#  [ 0.14051724]
#  [ 0.18579024]
#  [ 0.02988221]
#  [ 0.126411  ]
#  [ 0.12239213]
#  [ 0.09653597]
#  [ 0.09773481]
#  [ 0.19021652]
#  [ 0.17364935]
#  [ 0.11873578]
#  [ 0.09411292]
#  [ 0.06700962]
#  [ 0.05692715]
#  [ 0.15186518]
#  [ 0.10218889]
#  [ 0.00647879]
#  [ 0.12678476]
#  [-0.00727295]
#  [ 0.04925303]
#  [ 0.16115559]
#  [ 0.11146301]
#  [ 0.05733913]
#  [ 0.14902303]
#  [ 0.12197216]
#  [ 0.11669937]
#  [ 0.13610902]
#  [-0.00486216]
#  [ 0.04440222]
#  [ 0.05170838]
#  [ 0.07837263]
#  [ 0.0839991 ]
#  [ 0.04281232]
#  [ 0.07552562]
#  [ 0.10865307]
#  [ 0.14581701]
#  [ 0.10261738]
#  [ 0.07878254]
#  [ 0.07915526]
#  [ 0.06905414]
#  [ 0.07390379]
#  [ 0.12196276]
#  [ 0.11188572]
#  [ 0.05369932]]
# guess rank = 1.0
# True
# theta (degrees) =
# [[179.99119365]]
# signal retrieved
# [[ 594742.28827673  554137.3301095   772967.26405911 ... 1349542.79763832
#   1238043.9747027   594189.87102101]
#  [ 554137.3301095   517181.18657524  720748.23407431 ... 1258345.9432316
#   1154382.34459979  554053.79011956]
#  [ 772967.26405911  720748.23407431 1005864.82925661 ... 1755344.77698146
#   1610317.90537502  772871.56830465]
#  ...
#  [1349542.79763832 1258345.9432316  1755344.77698146 ... 3065155.68661877
#   2811459.33537076 1349358.75667907]
#  [1238043.9747027  1154382.34459979 1610317.90537502 ... 2811459.33537076
#   2579609.36930757 1237868.78453655]
#  [ 594189.87102101  554053.79011956  772871.56830465 ... 1349358.75667907
#   1237868.78453655  594608.63391969]]
# signal:
# [[ 3]
#  [-5]
#  [-6]
#  ...
#  [-7]
#  [-6]
#  [ 7]]
# Sparce matrix
# zero eigenvalues = 0.0
# corresponding eigenvectors:
# []
# signal eigenvalues:
# [2.0603505e+08]
# corresponding eigenvectors:
# [[ 0.05369324]
#  [ 0.05007717]
#  [ 0.06989013]
#  [ 0.03876817]
#  [ 0.06058641]
#  [ 0.07064984]
#  [ 0.02869018]
#  [ 0.08926137]
#  [ 0.0581572 ]
#  [ 0.1009869 ]
#  [-0.00281429]
#  [ 0.07995907]
#  [ 0.06217245]
#  [ 0.10016171]
#  [ 0.07431743]
#  [ 0.12359033]
#  [ 0.16233762]
#  [ 0.09250171]
#  [ 0.12641097]
#  [ 0.06298574]
#  [ 0.03475765]
#  [ 0.21002992]
#  [ 0.1357113 ]
#  [ 0.04439967]
#  [ 0.02018774]
#  [ 0.09813716]
#  [ 0.09088801]
#  [ 0.02546801]
#  [ 0.0242377 ]
#  [ 0.14780617]
#  [ 0.06543338]
#  [ 0.08278778]
#  [ 0.06301128]
#  [ 0.03553785]
#  [ 0.10942919]
#  [ 0.08320639]
#  [ 0.05050118]
#  [ 0.10944483]
#  [ 0.13731773]
#  [ 0.12320195]
#  [ 0.11753181]
#  [ 0.14417558]
#  [ 0.01817657]
#  [ 0.08479951]
#  [ 0.07956421]
#  [ 0.03593739]
#  [ 0.12277834]
#  [ 0.07998814]
#  [ 0.11589958]
#  [ 0.18334874]
#  [ 0.08926783]
#  [ 0.15185521]
#  [ 0.11630473]
#  [ 0.08077469]
#  [ 0.06141139]
#  [ 0.0460391 ]
#  [ 0.09004613]
#  [ 0.14052952]
#  [ 0.18578433]
#  [ 0.02988566]
#  [ 0.12641234]
#  [ 0.1223562 ]
#  [ 0.09654517]
#  [ 0.09773779]
#  [ 0.19021135]
#  [ 0.17367231]
#  [ 0.11873398]
#  [ 0.09410665]
#  [ 0.06702079]
#  [ 0.05693724]
#  [ 0.15182759]
#  [ 0.10217693]
#  [ 0.00648014]
#  [ 0.12681898]
#  [-0.0072657 ]
#  [ 0.0492404 ]
#  [ 0.161106  ]
#  [ 0.1114518 ]
#  [ 0.05734871]
#  [ 0.1490362 ]
#  [ 0.12198185]
#  [ 0.11670854]
#  [ 0.13608914]
#  [-0.00485121]
#  [ 0.04445814]
#  [ 0.05169276]
#  [ 0.07834389]
#  [ 0.08400457]
#  [ 0.04280466]
#  [ 0.07553203]
#  [ 0.10863962]
#  [ 0.14578934]
#  [ 0.10261337]
#  [ 0.07874693]
#  [ 0.07914452]
#  [ 0.06905158]
#  [ 0.07392   ]
#  [ 0.12196478]
#  [ 0.11186391]
#  [ 0.05372727]]
# guess rank = 1.0
# True
# theta (degrees) =
# [[179.99205055]]
# signal retrieved
# [[ 594457.6376585   553997.66524657  773175.23936116 ... 1349256.32844334
#   1237512.21333452  594382.24792506]
#  [ 553997.66524657  517172.3207238   721106.95053342 ... 1258373.39372933
#   1154159.90159488  554345.57226535]
#  [ 773175.23936116  721106.95053342 1006864.8161684  ... 1756260.85543596
#   1610815.34676019  773667.65693218]
#  ...
#  [1349256.32844334 1258373.39372933 1756260.85543596 ... 3065326.61458417
#   2811019.88816087 1350115.43147044]
#  [1237512.21333452 1154159.90159488 1610815.34676019 ... 2811019.88816087
#   2578664.15876837 1238297.52215443]
#  [ 594382.24792506  554345.57226535  773667.65693218 ... 1350115.43147044
#   1238297.52215443  595266.78016713]]
# signal:
# [[ 3]
#  [-5]
#  [-6]
#  ...
#  [-7]
#  [-6]
#  [ 7]]
# Sparce matrix
# zero eigenvalues = 0.0
# corresponding eigenvectors:
# []
# signal eigenvalues:
# [2.05983592e+08]
# corresponding eigenvectors:
# [[ 0.05369929]
#  [ 0.05009211]
#  [ 0.06985899]
#  [ 0.03876848]
#  [ 0.06056754]
#  [ 0.07068196]
#  [ 0.02869332]
#  [ 0.0892369 ]
#  [ 0.05818094]
#  [ 0.10096409]
#  [-0.00280749]
#  [ 0.07999624]
#  [ 0.06220889]
#  [ 0.10017049]
#  [ 0.0743189 ]
#  [ 0.12357989]
#  [ 0.16235315]
#  [ 0.09246109]
#  [ 0.12641351]
#  [ 0.06301617]
#  [ 0.03473447]
#  [ 0.20999024]
#  [ 0.1357099 ]
#  [ 0.04440995]
#  [ 0.02019945]
#  [ 0.09816602]
#  [ 0.09087005]
#  [ 0.02541211]
#  [ 0.02424527]
#  [ 0.14780579]
#  [ 0.06539775]
#  [ 0.08278047]
#  [ 0.06301427]
#  [ 0.03552791]
#  [ 0.10945019]
#  [ 0.08319841]
#  [ 0.05048592]
#  [ 0.10941914]
#  [ 0.13735005]
#  [ 0.1231821 ]
#  [ 0.11752857]
#  [ 0.14420538]
#  [ 0.01815649]
#  [ 0.08480723]
#  [ 0.07957669]
#  [ 0.03591446]
#  [ 0.12276919]
#  [ 0.0799571 ]
#  [ 0.11592349]
#  [ 0.18337008]
#  [ 0.0892475 ]
#  [ 0.15184271]
#  [ 0.11627379]
#  [ 0.08077928]
#  [ 0.06138144]
#  [ 0.04604074]
#  [ 0.09003456]
#  [ 0.14056851]
#  [ 0.18575462]
#  [ 0.02989807]
#  [ 0.12638726]
#  [ 0.12236585]
#  [ 0.0965269 ]
#  [ 0.09770686]
#  [ 0.19021691]
#  [ 0.17366898]
#  [ 0.11872379]
#  [ 0.09411345]
#  [ 0.0670335 ]
#  [ 0.056955  ]
#  [ 0.15185692]
#  [ 0.10219808]
#  [ 0.00645175]
#  [ 0.12679439]
#  [-0.00726577]
#  [ 0.04930533]
#  [ 0.16115577]
#  [ 0.11146543]
#  [ 0.05736332]
#  [ 0.14904579]
#  [ 0.12195244]
#  [ 0.11672285]
#  [ 0.13608817]
#  [-0.00483334]
#  [ 0.04439794]
#  [ 0.05169797]
#  [ 0.07833613]
#  [ 0.0840097 ]
#  [ 0.04280414]
#  [ 0.07552629]
#  [ 0.10866519]
#  [ 0.14580991]
#  [ 0.10257944]
#  [ 0.07876292]
#  [ 0.07915062]
#  [ 0.06908414]
#  [ 0.07391316]
#  [ 0.12196789]
#  [ 0.11185043]
#  [ 0.05369022]]
# guess rank = 1.0
# True
# theta (degrees) =
# [[179.99078898]]
# signal retrieved
# [[ 594440.54527372  554078.19093884  772721.87810644 ... 1349109.24358924
#   1237202.75871376  593882.33035538]
#  [ 554078.19093884  517353.97355405  720821.72879085 ... 1258476.98215863
#   1154079.33510732  553991.32154355]
#  [ 772721.87810644  720821.72879085 1005706.878751   ... 1755086.50607549
#   1609493.27543235  772601.98500234]
#  ...
#  [1349109.24358924 1258476.98215863 1755086.50607549 ... 3064727.80833893
#   2810060.19320676 1348869.29795981]
#  [1237202.75871376 1154079.33510732 1609493.27543235 ... 2810060.19320676
#   2577411.66706021 1236983.91077064]
#  [ 593882.33035538  553991.32154355  772601.98500234 ... 1348869.29795981
#   1236983.91077064  594282.81240441]]
# signal:
# [[ 3]
#  [-5]
#  [-6]
#  ...
#  [-7]
#  [-6]
#  [ 7]]
# Sparce matrix
# zero eigenvalues = 0.0
# corresponding eigenvectors:
# []
# signal eigenvalues:
# [2.06006356e+08]
# corresponding eigenvectors:
# [[ 0.05372672]
#  [ 0.05007277]
#  [ 0.06986777]
#  [ 0.03878964]
#  [ 0.06059488]
#  [ 0.07068496]
#  [ 0.02866284]
#  [ 0.08924876]
#  [ 0.05816856]
#  [ 0.1009599 ]
#  [-0.00282601]
#  [ 0.07998632]
#  [ 0.06218677]
#  [ 0.10017792]
#  [ 0.07430894]
#  [ 0.1235688 ]
#  [ 0.16235439]
#  [ 0.09250256]
#  [ 0.1264254 ]
#  [ 0.06302009]
#  [ 0.03472757]
#  [ 0.21001854]
#  [ 0.13568906]
#  [ 0.04441402]
#  [ 0.02020741]
#  [ 0.09812344]
#  [ 0.09086343]
#  [ 0.02545785]
#  [ 0.02423038]
#  [ 0.14779163]
#  [ 0.06542134]
#  [ 0.08280024]
#  [ 0.06300427]
#  [ 0.03553721]
#  [ 0.1094578 ]
#  [ 0.08320572]
#  [ 0.05048385]
#  [ 0.10943289]
#  [ 0.13733201]
#  [ 0.12320362]
#  [ 0.11754787]
#  [ 0.14419681]
#  [ 0.01818094]
#  [ 0.08477505]
#  [ 0.07956364]
#  [ 0.03595625]
#  [ 0.1227577 ]
#  [ 0.07998351]
#  [ 0.11591219]
#  [ 0.18332672]
#  [ 0.08926181]
#  [ 0.1518659 ]
#  [ 0.11630164]
#  [ 0.08079317]
#  [ 0.06139807]
#  [ 0.04604014]
#  [ 0.09007629]
#  [ 0.14053529]
#  [ 0.18577327]
#  [ 0.02988676]
#  [ 0.12639178]
#  [ 0.12237741]
#  [ 0.09652821]
#  [ 0.09774652]
#  [ 0.19022512]
#  [ 0.17363557]
#  [ 0.11871853]
#  [ 0.09415113]
#  [ 0.06702729]
#  [ 0.05694464]
#  [ 0.15184535]
#  [ 0.10221222]
#  [ 0.00644917]
#  [ 0.12681547]
#  [-0.0072707 ]
#  [ 0.04925666]
#  [ 0.16113823]
#  [ 0.11144069]
#  [ 0.05732327]
#  [ 0.14901741]
#  [ 0.12195743]
#  [ 0.11671173]
#  [ 0.13611299]
#  [-0.00486   ]
#  [ 0.04444825]
#  [ 0.05168865]
#  [ 0.07832664]
#  [ 0.08402288]
#  [ 0.04282241]
#  [ 0.0755257 ]
#  [ 0.10865786]
#  [ 0.14578071]
#  [ 0.10255318]
#  [ 0.07876375]
#  [ 0.07912476]
#  [ 0.06905718]
#  [ 0.07391734]
#  [ 0.12197656]
#  [ 0.11185979]
#  [ 0.05370423]]
# guess rank = 1.0
# True
# theta (degrees) =
# [[179.99122403]]
# signal retrieved
# [[ 595100.86768314  554211.53134591  773294.16226071 ... 1350047.98259104
#   1238076.34127851  594418.10455849]
#  [ 554211.53134591  517012.54439535  720704.93470346 ... 1258221.00997054
#   1153862.52303533  553979.0191388 ]
#  [ 773294.16226071  720704.93470346 1006068.74431647 ... 1755625.86153035
#   1610014.6998977   772983.7527461 ]
#  ...
#  [1350047.98259104 1258221.00997054 1755625.86153035 ... 3065485.43487148
#   2810789.82349863 1349472.90297945]
#  [1238076.34127851 1153862.52303533 1610014.6998977  ... 2810789.82349863
#   2578134.07105948 1237552.98785941]
#  [ 594418.10455849  553979.0191388   772983.7527461  ... 1349472.90297945
#   1237552.98785941  594648.86793103]]
# signal:
# [[ 3]
#  [-5]
#  [-6]
#  ...
#  [-7]
#  [-6]
#  [ 7]]
# Sparce matrix
# zero eigenvalues = 0.0
# corresponding eigenvectors:
# []
# signal eigenvalues:
# [2.06009705e+08]
# corresponding eigenvectors:
# [[ 0.05373637]
#  [ 0.05008858]
#  [ 0.06986876]
#  [ 0.03876371]
#  [ 0.06056138]
#  [ 0.0706728 ]
#  [ 0.02867356]
#  [ 0.08925487]
#  [ 0.05816008]
#  [ 0.10095785]
#  [-0.00283043]
#  [ 0.07996885]
#  [ 0.06220825]
#  [ 0.10018129]
#  [ 0.07433465]
#  [ 0.12360043]
#  [ 0.16237254]
#  [ 0.09247643]
#  [ 0.12638102]
#  [ 0.06296735]
#  [ 0.03475161]
#  [ 0.21001028]
#  [ 0.13571597]
#  [ 0.04442174]
#  [ 0.02021142]
#  [ 0.09811033]
#  [ 0.09087531]
#  [ 0.02545372]
#  [ 0.02423543]
#  [ 0.14782712]
#  [ 0.06540884]
#  [ 0.08280291]
#  [ 0.06297375]
#  [ 0.03555141]
#  [ 0.10945335]
#  [ 0.08320319]
#  [ 0.05049314]
#  [ 0.10945693]
#  [ 0.13731396]
#  [ 0.12315952]
#  [ 0.11749427]
#  [ 0.14418214]
#  [ 0.01820282]
#  [ 0.08481463]
#  [ 0.07956455]
#  [ 0.03592459]
#  [ 0.1227817 ]
#  [ 0.0799627 ]
#  [ 0.11590894]
#  [ 0.18331962]
#  [ 0.08926903]
#  [ 0.15186167]
#  [ 0.11632875]
#  [ 0.08076152]
#  [ 0.06141958]
#  [ 0.04605652]
#  [ 0.09004905]
#  [ 0.140539  ]
#  [ 0.18577426]
#  [ 0.02987673]
#  [ 0.12642953]
#  [ 0.12237865]
#  [ 0.09650858]
#  [ 0.09772351]
#  [ 0.19021555]
#  [ 0.17366522]
#  [ 0.11873236]
#  [ 0.0940997 ]
#  [ 0.06700981]
#  [ 0.05695418]
#  [ 0.1518944 ]
#  [ 0.10218372]
#  [ 0.00645191]
#  [ 0.12681072]
#  [-0.00725611]
#  [ 0.04927743]
#  [ 0.16113643]
#  [ 0.11145923]
#  [ 0.05735934]
#  [ 0.1490251 ]
#  [ 0.12196437]
#  [ 0.11672919]
#  [ 0.13609919]
#  [-0.00484076]
#  [ 0.04442945]
#  [ 0.0516826 ]
#  [ 0.0783311 ]
#  [ 0.08396585]
#  [ 0.04281548]
#  [ 0.07550819]
#  [ 0.10862149]
#  [ 0.14581731]
#  [ 0.10257085]
#  [ 0.0787813 ]
#  [ 0.07914395]
#  [ 0.06905777]
#  [ 0.07390091]
#  [ 0.12199767]
#  [ 0.11184681]
#  [ 0.0536958 ]]
# guess rank = 1.0
# True
# theta (degrees) =
# [[179.99086111]]
# signal retrieved
# [[ 595332.10529827  554505.38629713  773458.70807026 ... 1350531.27509653
#   1238171.80200228  594429.77469825]
#  [ 554505.38629713  517354.50085517  720955.96078947 ... 1258856.87759008
#   1154115.05454236  554071.75322375]
#  [ 773458.70807026  720955.96078947 1006110.63910272 ... 1755992.62221254
#   1609874.51162336  772889.90375171]
#  ...
#  [1350531.27509653 1258856.87759008 1755992.62221254 ... 3066605.21483332
#   2811001.41119142 1349508.96694321]
#  [1238171.80200228 1154115.05454236 1609874.51162336 ... 2811001.41119142
#   2577586.83899378 1237236.64746496]
#  [ 594429.77469825  554071.75322375  772889.90375171 ... 1349508.96694321
#   1237236.64746496  594483.87173055]]
# signal:
# [[ 3]
#  [-5]
#  [-6]
#  ...
#  [-7]
#  [-6]
#  [ 7]]
# Sparce matrix
# zero eigenvalues = 0.0
# corresponding eigenvectors:
# []
# signal eigenvalues:
# [2.05991966e+08]
# corresponding eigenvectors:
# [[ 0.05371759]
#  [ 0.05009519]
#  [ 0.06986637]
#  [ 0.03877252]
#  [ 0.0605597 ]
#  [ 0.07067373]
#  [ 0.02869857]
#  [ 0.08923266]
#  [ 0.05815459]
#  [ 0.10095193]
#  [-0.00284658]
#  [ 0.07995071]
#  [ 0.06218749]
#  [ 0.10013209]
#  [ 0.07428727]
#  [ 0.12357007]
#  [ 0.16235515]
#  [ 0.09247478]
#  [ 0.12639936]
#  [ 0.06298957]
#  [ 0.03472716]
#  [ 0.21000987]
#  [ 0.13566587]
#  [ 0.04441475]
#  [ 0.0201863 ]
#  [ 0.09814626]
#  [ 0.09087513]
#  [ 0.02544615]
#  [ 0.02421044]
#  [ 0.14784461]
#  [ 0.06543014]
#  [ 0.08276347]
#  [ 0.06301598]
#  [ 0.03552726]
#  [ 0.10944092]
#  [ 0.08319671]
#  [ 0.05045845]
#  [ 0.10942818]
#  [ 0.13728138]
#  [ 0.12317442]
#  [ 0.1175243 ]
#  [ 0.14417962]
#  [ 0.01818046]
#  [ 0.08483307]
#  [ 0.07957514]
#  [ 0.03596163]
#  [ 0.12276823]
#  [ 0.07995103]
#  [ 0.1158928 ]
#  [ 0.18335337]
#  [ 0.08926542]
#  [ 0.15187018]
#  [ 0.11632214]
#  [ 0.08077137]
#  [ 0.06136844]
#  [ 0.0460309 ]
#  [ 0.09007096]
#  [ 0.14056393]
#  [ 0.18578932]
#  [ 0.02986074]
#  [ 0.12638926]
#  [ 0.12237223]
#  [ 0.09653045]
#  [ 0.09774837]
#  [ 0.19022722]
#  [ 0.17367333]
#  [ 0.1187481 ]
#  [ 0.09409481]
#  [ 0.06705352]
#  [ 0.05693248]
#  [ 0.15186805]
#  [ 0.1021739 ]
#  [ 0.00645674]
#  [ 0.12682283]
#  [-0.00726991]
#  [ 0.04928696]
#  [ 0.16114329]
#  [ 0.11147041]
#  [ 0.05736051]
#  [ 0.14904066]
#  [ 0.12199659]
#  [ 0.11672361]
#  [ 0.13609644]
#  [-0.00482854]
#  [ 0.04442297]
#  [ 0.05169086]
#  [ 0.07836144]
#  [ 0.08402493]
#  [ 0.04280286]
#  [ 0.07553868]
#  [ 0.10862542]
#  [ 0.14580097]
#  [ 0.1025811 ]
#  [ 0.07874252]
#  [ 0.079157  ]
#  [ 0.06906101]
#  [ 0.0739003 ]
#  [ 0.12198578]
#  [ 0.1118696 ]
#  [ 0.05368143]]
# guess rank = 1.0
# True
# theta (degrees) =
# [[179.99183643]]
# signal retrieved
# [[ 594863.70412455  554336.2833531   773092.33487868 ... 1349814.55935227
#   1237884.54227284  594011.47850119]
#  [ 554336.2833531   517441.30372226  720969.59624099 ... 1258794.73109412
#   1154393.7988824   553951.35026872]
#  [ 773092.33487868  720969.59624099 1005962.97272197 ... 1755597.79752434
#   1610012.03644884  772586.9675825 ]
#  ...
#  [1349814.55935227 1258794.73109412 1755597.79752434 ... 3065749.50828172
#   2811057.66154438 1348905.46487368]
#  [1237884.54227284 1154393.7988824  1610012.03644884 ... 2811057.66154438
#   2578399.11266741 1237045.61906568]
#  [ 594011.47850119  553951.35026872  772586.9675825  ... 1348905.46487368
#   1237045.61906568  594107.00932964]]
# signal:
# [[ 3]
#  [-5]
#  [-6]
#  ...
#  [-7]
#  [-6]
#  [ 7]]
# Sparce matrix
# zero eigenvalues = 0.0
# corresponding eigenvectors:
# []
# signal eigenvalues:
# [2.06031334e+08]
# corresponding eigenvectors:
# [[ 0.05373933]
#  [ 0.05006257]
#  [ 0.06987749]
#  [ 0.03878645]
#  [ 0.06058669]
#  [ 0.07068241]
#  [ 0.02865531]
#  [ 0.0892603 ]
#  [ 0.05814744]
#  [ 0.10097751]
#  [-0.0028119 ]
#  [ 0.07995916]
#  [ 0.06217983]
#  [ 0.10016492]
#  [ 0.07432407]
#  [ 0.12358726]
#  [ 0.16234956]
#  [ 0.0925007 ]
#  [ 0.12640762]
#  [ 0.0630139 ]
#  [ 0.03471512]
#  [ 0.21002415]
#  [ 0.13569844]
#  [ 0.04442599]
#  [ 0.02017049]
#  [ 0.09814478]
#  [ 0.09083224]
#  [ 0.02544768]
#  [ 0.02423325]
#  [ 0.14781015]
#  [ 0.0654426 ]
#  [ 0.08280353]
#  [ 0.06297862]
#  [ 0.03555548]
#  [ 0.10942241]
#  [ 0.08319043]
#  [ 0.05047527]
#  [ 0.10942679]
#  [ 0.13732282]
#  [ 0.12317648]
#  [ 0.11753463]
#  [ 0.14417125]
#  [ 0.01817067]
#  [ 0.0848288 ]
#  [ 0.0795381 ]
#  [ 0.03595767]
#  [ 0.12277175]
#  [ 0.07996494]
#  [ 0.11591557]
#  [ 0.18335815]
#  [ 0.0892321 ]
#  [ 0.15185663]
#  [ 0.11631128]
#  [ 0.08078291]
#  [ 0.06138672]
#  [ 0.04606081]
#  [ 0.09010576]
#  [ 0.14054836]
#  [ 0.18574312]
#  [ 0.02987511]
#  [ 0.12641115]
#  [ 0.12237573]
#  [ 0.09655873]
#  [ 0.0977411 ]
#  [ 0.19021553]
#  [ 0.17365648]
#  [ 0.11873761]
#  [ 0.09410183]
#  [ 0.06705529]
#  [ 0.05692565]
#  [ 0.1518483 ]
#  [ 0.10218364]
#  [ 0.00645324]
#  [ 0.12679054]
#  [-0.00726733]
#  [ 0.04924953]
#  [ 0.16112418]
#  [ 0.11145504]
#  [ 0.05733398]
#  [ 0.14901244]
#  [ 0.12198012]
#  [ 0.11673443]
#  [ 0.13611566]
#  [-0.00483054]
#  [ 0.04446538]
#  [ 0.0516925 ]
#  [ 0.07835474]
#  [ 0.08401833]
#  [ 0.0427928 ]
#  [ 0.07551812]
#  [ 0.10863192]
#  [ 0.14580093]
#  [ 0.10257328]
#  [ 0.07874452]
#  [ 0.07916293]
#  [ 0.06905316]
#  [ 0.07389182]
#  [ 0.12196399]
#  [ 0.11189852]
#  [ 0.0537352 ]]
# guess rank = 1.0
# True
# theta (degrees) =
# [[179.99144006]]
# signal retrieved
# [[ 595470.43715839  554305.61292773  773680.24300019 ... 1350380.72716812
#   1238939.05312082  594957.53947494]
#  [ 554305.61292773  516851.5448352   720744.53349439 ... 1257995.95817541
#   1154164.95354455  554254.8932134 ]
#  [ 773680.24300019  720744.53349439 1006486.57648506 ... 1755905.810194
#   1611003.28136632  773628.91129594]
#  ...
#  [1350380.72716812 1257995.95817541 1755905.810194   ... 3065221.29892077
#   2811817.87495543 1350278.44457893]
#  [1238939.05312082 1154164.95354455 1611003.28136632 ... 2811817.87495543
#   2580223.02075195 1238836.6679518 ]
#  [ 594957.53947494  554254.8932134   773628.91129594 ... 1350278.44457893
#   1238836.6679518   595413.32217668]]
# signal:
# [[ 3]
#  [-5]
#  [-6]
#  ...
#  [-7]
#  [-6]
#  [ 7]]
# Sparce matrix
# zero eigenvalues = 0.0
# corresponding eigenvectors:
# []
# signal eigenvalues:
# [2.06045235e+08]
# corresponding eigenvectors:
# [[ 0.05371634]
#  [ 0.05007725]
#  [ 0.06986886]
#  [ 0.03877083]
#  [ 0.06059146]
#  [ 0.07071706]
#  [ 0.02869826]
#  [ 0.08926114]
#  [ 0.05816186]
#  [ 0.10096542]
#  [-0.00284422]
#  [ 0.0799623 ]
#  [ 0.06221962]
#  [ 0.1001641 ]
#  [ 0.07431322]
#  [ 0.12356906]
#  [ 0.16233994]
#  [ 0.09246399]
#  [ 0.12639305]
#  [ 0.06300823]
#  [ 0.03475165]
#  [ 0.20999584]
#  [ 0.13570352]
#  [ 0.04441514]
#  [ 0.02022905]
#  [ 0.09815196]
#  [ 0.09088171]
#  [ 0.02542097]
#  [ 0.02423587]
#  [ 0.14780227]
#  [ 0.06546715]
#  [ 0.0828092 ]
#  [ 0.06301481]
#  [ 0.03550281]
#  [ 0.10943398]
#  [ 0.08320898]
#  [ 0.05048747]
#  [ 0.10943191]
#  [ 0.13730727]
#  [ 0.12318187]
#  [ 0.11753528]
#  [ 0.14416737]
#  [ 0.01815961]
#  [ 0.0848301 ]
#  [ 0.07958616]
#  [ 0.03599585]
#  [ 0.12277457]
#  [ 0.07998234]
#  [ 0.11592691]
#  [ 0.18335939]
#  [ 0.08927416]
#  [ 0.15183153]
#  [ 0.11629623]
#  [ 0.08076883]
#  [ 0.06138844]
#  [ 0.04605608]
#  [ 0.09004673]
#  [ 0.14056505]
#  [ 0.18578703]
#  [ 0.02991979]
#  [ 0.12642323]
#  [ 0.12237229]
#  [ 0.09652608]
#  [ 0.09772577]
#  [ 0.19024429]
#  [ 0.17361587]
#  [ 0.11875903]
#  [ 0.09406476]
#  [ 0.06705499]
#  [ 0.05694814]
#  [ 0.15183977]
#  [ 0.10218044]
#  [ 0.00645424]
#  [ 0.12681551]
#  [-0.00723299]
#  [ 0.04928734]
#  [ 0.16115717]
#  [ 0.11145925]
#  [ 0.05734159]
#  [ 0.14902517]
#  [ 0.12197177]
#  [ 0.1166981 ]
#  [ 0.13606536]
#  [-0.00486807]
#  [ 0.04444045]
#  [ 0.05170228]
#  [ 0.07834434]
#  [ 0.08399741]
#  [ 0.04281507]
#  [ 0.07552123]
#  [ 0.10867475]
#  [ 0.14580396]
#  [ 0.10258032]
#  [ 0.07874611]
#  [ 0.07916293]
#  [ 0.06905137]
#  [ 0.07387154]
#  [ 0.12194274]
#  [ 0.11186195]
#  [ 0.05371325]]
# guess rank = 1.0
# True
# theta (degrees) =
# [[179.98961912]]
# signal retrieved
# [[ 594992.92646457  554265.35344684  773312.76145253 ... 1349654.76952637
#   1238092.81021091  594512.78194836]
#  [ 554265.35344684  517203.11226888  720915.14755415 ... 1258228.38319446
#   1154197.47917662  554226.50828936]
#  [ 773312.76145253  720915.14755415 1006314.31134764 ... 1755497.08375636
#   1610378.23471531  773267.23882162]
#  ...
#  [1349654.76952637 1258228.38319446 1755497.08375636 ... 3064375.05015488
#   2810604.00114935 1349579.06120584]
#  [1238092.81021091 1154197.47917662 1610378.23471531 ... 2810604.00114935
#   2578714.11008645 1238014.86257056]
#  [ 594512.78194836  554226.50828936  773267.23882162 ... 1349579.06120584
#   1238014.86257056  594966.02543392]]
# signal:
# [[ 3]
#  [-5]
#  [-6]
#  ...
#  [-7]
#  [-6]
#  [ 7]]
# Sparce matrix
# zero eigenvalues = 0.0
# corresponding eigenvectors:
# []
# signal eigenvalues:
# [2.06017387e+08]
# corresponding eigenvectors:
# [[ 0.05372535]
#  [ 0.05007411]
#  [ 0.0698451 ]
#  [ 0.03880351]
#  [ 0.06056971]
#  [ 0.07068671]
#  [ 0.02867847]
#  [ 0.08926862]
#  [ 0.05815879]
#  [ 0.10096492]
#  [-0.00281829]
#  [ 0.07995173]
#  [ 0.06221155]
#  [ 0.10015441]
#  [ 0.07432446]
#  [ 0.12359402]
#  [ 0.16236989]
#  [ 0.09248534]
#  [ 0.12639631]
#  [ 0.06299646]
#  [ 0.0347327 ]
#  [ 0.21001828]
#  [ 0.13568345]
#  [ 0.04441061]
#  [ 0.02020702]
#  [ 0.09813991]
#  [ 0.09087058]
#  [ 0.02546258]
#  [ 0.02422291]
#  [ 0.14782719]
#  [ 0.06541616]
#  [ 0.08277688]
#  [ 0.06299682]
#  [ 0.03553376]
#  [ 0.10945861]
#  [ 0.08318532]
#  [ 0.05048632]
#  [ 0.10942141]
#  [ 0.13730336]
#  [ 0.12318817]
#  [ 0.11751897]
#  [ 0.14418389]
#  [ 0.0181657 ]
#  [ 0.08483974]
#  [ 0.07958416]
#  [ 0.03595217]
#  [ 0.12276783]
#  [ 0.07996123]
#  [ 0.11590328]
#  [ 0.18338183]
#  [ 0.08923869]
#  [ 0.15184706]
#  [ 0.11632231]
#  [ 0.08076665]
#  [ 0.06138296]
#  [ 0.04601504]
#  [ 0.09004242]
#  [ 0.14053577]
#  [ 0.18577746]
#  [ 0.02989247]
#  [ 0.1263872 ]
#  [ 0.12239506]
#  [ 0.09653063]
#  [ 0.09773647]
#  [ 0.19021887]
#  [ 0.17367655]
#  [ 0.11874043]
#  [ 0.09410742]
#  [ 0.06700711]
#  [ 0.05698262]
#  [ 0.15186287]
#  [ 0.10219223]
#  [ 0.00650957]
#  [ 0.12679491]
#  [-0.00728904]
#  [ 0.04927493]
#  [ 0.16113664]
#  [ 0.11144766]
#  [ 0.0573362 ]
#  [ 0.1490407 ]
#  [ 0.12193197]
#  [ 0.11673679]
#  [ 0.13609366]
#  [-0.00484723]
#  [ 0.04442835]
#  [ 0.05170668]
#  [ 0.07836124]
#  [ 0.08396171]
#  [ 0.04282155]
#  [ 0.07554263]
#  [ 0.10861677]
#  [ 0.14579701]
#  [ 0.10255239]
#  [ 0.07877785]
#  [ 0.07916164]
#  [ 0.0690555 ]
#  [ 0.0738965 ]
#  [ 0.12196888]
#  [ 0.11187426]
#  [ 0.05371081]]
# guess rank = 1.0
# True
# theta (degrees) =
# [[179.9909625]]
# signal retrieved
# [[ 595112.05413814  554243.10273283  773066.36467877 ... 1349992.80884985
#   1238260.51207675  594500.64436295]
#  [ 554243.10273283  517061.61457069  720530.44548956 ... 1258248.04863573
#   1154096.81345222  554089.10001809]
#  [ 773066.36467877  720530.44548956 1005473.73372319 ... 1755042.87857126
#   1609803.84482016  772865.36042955]
#  ...
#  [1349992.80884985 1258248.04863573 1755042.87857126 ... 3065257.73529848
#   2811128.99000292 1349628.15919307]
#  [1238260.51207675 1154096.81345222 1609803.84482016 ... 2811128.99000292
#   2578927.7006991  1237931.11429926]
#  [ 594500.64436295  554089.10001809  772865.36042955 ... 1349628.15919307
#   1237931.11429926  594839.07169962]]
# signal:
# [[ 3]
#  [-5]
#  [-6]
#  ...
#  [-7]
#  [-6]
#  [ 7]]
# Sparce matrix
# zero eigenvalues = 0.0
# corresponding eigenvectors:
# []
# signal eigenvalues:
# [2.06014381e+08]
# corresponding eigenvectors:
# [[ 0.05371644]
#  [ 0.05007963]
#  [ 0.06986872]
#  [ 0.0387777 ]
#  [ 0.06057973]
#  [ 0.07068083]
#  [ 0.02867833]
#  [ 0.0892516 ]
#  [ 0.05816304]
#  [ 0.10096524]
#  [-0.00282527]
#  [ 0.07996489]
#  [ 0.06219653]
#  [ 0.1001589 ]
#  [ 0.07431459]
#  [ 0.12358338]
#  [ 0.16235398]
#  [ 0.0924843 ]
#  [ 0.1263992 ]
#  [ 0.0629997 ]
#  [ 0.03473815]
#  [ 0.210013  ]
#  [ 0.13569691]
#  [ 0.04441742]
#  [ 0.02019395]
#  [ 0.09813493]
#  [ 0.09086778]
#  [ 0.02544373]
#  [ 0.02423112]
#  [ 0.14781725]
#  [ 0.06542544]
#  [ 0.08279032]
#  [ 0.0630014 ]
#  [ 0.03554057]
#  [ 0.10944459]
#  [ 0.08320069]
#  [ 0.05048518]
#  [ 0.10943606]
#  [ 0.13731251]
#  [ 0.12318206]
#  [ 0.11752438]
#  [ 0.14418409]
#  [ 0.0181766 ]
#  [ 0.08481577]
#  [ 0.07956696]
#  [ 0.03594772]
#  [ 0.12277247]
#  [ 0.07997008]
#  [ 0.11591163]
#  [ 0.18335533]
#  [ 0.08925594]
#  [ 0.1518537 ]
#  [ 0.1163093 ]
#  [ 0.0807759 ]
#  [ 0.06139071]
#  [ 0.04604272]
#  [ 0.09005565]
#  [ 0.14054589]
#  [ 0.1857749 ]
#  [ 0.02988738]
#  [ 0.12640485]
#  [ 0.12237409]
#  [ 0.09653284]
#  [ 0.09772878]
#  [ 0.19022317]
#  [ 0.17365919]
#  [ 0.11873379]
#  [ 0.09410334]
#  [ 0.06703245]
#  [ 0.0569452 ]
#  [ 0.15185608]
#  [ 0.10218633]
#  [ 0.00646502]
#  [ 0.1268063 ]
#  [-0.00726499]
#  [ 0.04927042]
#  [ 0.16113805]
#  [ 0.11145948]
#  [ 0.0573457 ]
#  [ 0.14902817]
#  [ 0.12196775]
#  [ 0.11671957]
#  [ 0.13609644]
#  [-0.00484681]
#  [ 0.04443132]
#  [ 0.05169586]
#  [ 0.07834795]
#  [ 0.08400018]
#  [ 0.04280917]
#  [ 0.07552617]
#  [ 0.10864525]
#  [ 0.1458016 ]
#  [ 0.10257894]
#  [ 0.07876298]
#  [ 0.07915267]
#  [ 0.06905837]
#  [ 0.07389941]
#  [ 0.12196941]
#  [ 0.11186744]
#  [ 0.05370651]]
# guess rank = 1.0
# True
# theta (degrees) =
# [[179.9975915]]
# signal retrieved
# [[ 594907.20768409  554208.2917903   773189.86325783 ... 1349754.73302856
#   1237968.25335983  594342.81909021]
#  [ 554208.2917903   517173.50999345  720844.66251308 ... 1258368.56329251
#   1154142.08266258  554100.81457101]
#  [ 773189.86325783  720844.66251308 1006142.99322678 ... 1755616.82360522
#   1610213.39980391  773055.56831782]
#  ...
#  [1349754.73302856 1258368.56329251 1755616.82360522 ... 3065251.65826061
#   2810933.6117456  1349504.24476931]
#  [1237968.25335983 1154142.08266258 1610213.39980391 ... 2810933.6117456
#   2578579.59392977 1237734.82206299]
#  [ 594342.81909021  554100.81457101  773055.56831782 ... 1349504.24476931
#   1237734.82206299  594730.92295547]]
# <function matplotlib.pyplot.show(close=None, block=None)>
